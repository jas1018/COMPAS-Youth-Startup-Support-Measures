# %%
from geoband.API import *

# %%
import pandas as pd

df = pd.read_csv("./data/1.용인시_상권_정보.csv")

# %%
df
# Out:
#              gid  ws_cnt  found_age_1  found_age_2  found_age_3  found_age_4  \
# 0     다바67bb99aa       1            0            0            0            0
# 1     다바68aa99ba       1            0            0            0            1
# 2     다바68aa99bb       5            0            1            0            0
# 3     다바68ab99ba       3            0            0            1            0
# 4     다바68ba99ab      16            0            1            2            3
# ...          ...     ...          ...          ...          ...          ...
# 2252  다사92ab02bb       1            0            0            0            1
# 2253  다사92ab03aa       2            0            0            0            0
# 2254  다사92ab04ab       1            0            0            0            0
# 2255  다사92ab05ab       2            0            1            0            0
# 2256  다사92ba02bb       3            0            0            0            0
#
# ...

# %%
import folium
import json

map_osm = folium.Map(location=[37.2210864,127.1775537], 
               tiles='cartodbpositron',
               zoom_start=11)

rfile = open('./data/14.용인시_지적도.geojson', 'r', encoding='utf-8').read()
jsonData = json.loads(rfile)
jsonData
# Out:
# {'type': 'FeatureCollection',
#  'name': '용인시_지적도',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'properties': {'PNU': '4146110100103160004', 'JIBUN': '316-4대'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[127.20036148704595, 37.236540161975654],
#        [127.20053191243628, 37.23650960083352],
#        [127.20056404368697, 37.236471883453625],
#        [127.20056649057946, 37.23637384642753],
#        [127.20045336781918, 37.236382055742304],
#        [127.20041708775138, 37.236384819793656],
#        [127.20031861340328, 37.23639237365037],
#        [127.20036148704595, 37.236540161975654]]]]}},
#   {'type': 'Feature',
#    'properties': {'PNU': '4146110100103160003', 'JIBUN': '316-3대'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[127.20004902135472, 37.236596190131365],
#        [127.20036148704595, 37.236540161975654],
# ...

# %%
folium.GeoJson(data=jsonData).add_to(map_osm)
map_osm

# %%
print("asd")
